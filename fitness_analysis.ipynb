# %% [markdown]
# # EDA Notebook

# %% [markdown]
# ## 1. Importar librerías necesarias
# Importar pandas, numpy, matplotlib y seaborn para el análisis y visualización de datos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Cargar el archivo CSV
# Solicitar al usuario la ruta del archivo .csv y cargarlo en un DataFrame de pandas.

# %%
# Change this path to point to your data file
file_path = '../data/raw/gym_members_exercise_tracking_synthetic_data.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ## 3. Visualizar las primeras filas del dataset
# Mostrar las primeras filas del DataFrame usando head() para obtener una vista general de los datos.

# %%
df.head()
# Out:
#     Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.0  Female         86.7        1.86     174    152.0         74.0
# 1  26.0  Female         84.7        1.83     166    156.0         73.0
# 2  22.0    Male         64.8        1.85     187    166.0         64.0
# 3  54.0  Female         75.3        1.82     187    169.0         58.0
# 4  34.0  Female         52.8        1.74     177    169.0         66.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12            712.0     Strength            12.8
# 1                      1.00            833.0     Strength            27.9
# 2                      1.24           1678.0       Cardio            28.7
# 3                      1.45            628.0       Cardio            31.8
# 4                      1.60           1286.0     Strength            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %% [markdown]
# ## 4. Explorar información general del dataset
# Utilizar info() y shape para mostrar información sobre el número de filas, columnas y tipos de datos.

# %%
df.info()
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1790 non-null   float64
#  1   Gender                         1729 non-null   str
#  2   Weight (kg)                    1778 non-null   float64
#  3   Height (m)                     1774 non-null   float64
#  4   Max_BPM                        1779 non-null   str
#  5   Avg_BPM                        1770 non-null   float64
#  6   Resting_BPM                    1781 non-null   float64
#  7   Session_Duration (hours)       1777 non-null   float64
#  8   Calories_Burned                1777 non-null   float64
#  9   Workout_Type                   1739 non-null   str
#  10  Fat_Percentage                 1784 non-null   float64
#  11  Water_Intake (liters)          1776 non-null   float64
# ...

# %% [markdown]
# ## 5. Describir variables numéricas y categóricas
# Usar describe() para variables numéricas y value_counts() para variables categóricas.

# %%
# Numerical variables
df.describe()

# Categorical values (Example for a columnn)
# df['category_column'].value_counts()
# Out:
#                Age  Weight (kg)   Height (m)      Avg_BPM  Resting_BPM  \
# count  1790.000000  1778.000000  1774.000000  1770.000000  1781.000000
# mean     34.475419    67.606637     1.739233   146.259322    63.951151
# std      12.315728    19.861408     0.123892    15.219516     7.936502
# min      18.000000    40.000000     1.500000   120.000000    50.000000
# 25%      23.000000    52.300000     1.650000   133.250000    57.000000
# 50%      33.000000    65.300000     1.730000   146.000000    65.000000
# 75%      45.000000    80.100000     1.820000   160.000000    72.000000
# max      59.000000   129.900000     2.000000   169.000000    74.000000
#
#        Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count               1777.000000      1777.000000     1784.000000
# mean                   1.391598      1033.698931       23.509361
# std                    0.372342       328.049662        5.865557
# min                    0.500000       303.000000       10.000000
# ...

# %% [markdown]
# ## 6. Visualizar valores nulos y duplicados
# Identificar y visualizar la cantidad de valores nulos y filas duplicadas en el dataset.

# %%
# Null values
df.isnull().sum()

# Duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. Análisis univariado de variables numéricas
# Realizar histogramas y boxplots para analizar la distribución de las variables numéricas.

# %%
# Histogram for a numerical variable
# df['numeric_column'].hist()
# plt.show()

# Boxplot
# df.boxplot(column='numeric_column')
# plt.show()

# %% [markdown]
# ## 8. Análisis univariado de variables categóricas
# Realizar gráficos de barras para analizar la frecuencia de las variables categóricas.

# %%
# Bar plot for a categorical variable
# df['categorical_column'].value_counts().plot(kind='bar')
# plt.show()

# %% [markdown]
# ## 9. Análisis bivariado entre variables
# Explorar relaciones entre variables numéricas y categóricas mediante scatterplots y tablas cruzadas.

# %%
# Scatterplot
# plt.scatter(df['numeric_column_x'], df['numeric_column_y'])
# plt.show()

# Crosstab for two categorical variables   
# pd.crosstab(df['categorical_column1'], df['categorical_column2'])

# %% [markdown]
# ## 10. Visualización de correlaciones
# Calcular y visualizar la matriz de correlación entre variables numéricas usando un heatmap.

# %%
# Correlation matrix
numeric_df = df.select_dtypes(include=['number'])

corr = numeric_df.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True)
plt.title('Correlación entre variables numéricas')
plt.show()

# %%
df.to_csv('../data/processed/clean_dataset.csv', index=False)

# %% [markdown]
# # Conclusiones
#
# 1. La duración del entrenamiento está relacionada con las calorías quemadas: cuanto más dura la sesión, mayor suele ser el gasto calórico.
#
# 2. Las variables físicas como peso, altura e IMC ayudan a entender mejor las diferencias entre usuarios.
#
# 3. El dataset permite comparar distintos perfiles de entrenamiento según género, tipo de entrenamiento y calorías quemadas.
